# %%
#Class: https://openclassrooms.com/fr/courses/4452741-decouvrez-les-librairies-python-pour-la-data-science/5574866-manipulez-les-donnees-contenues-dans-vos-dataframes

# %%
import pandas as pd

# %%
#https://www.kaggle.com/ikiulian/global-hospital-beds-capacity-for-covid19/data#
df = pd.read_csv("./dataset.csv")

# %%
df.head()
# Out:
#   country state          county        lat         lng   type  measure  \
# 0      US    AK  aleutians east  63.588753 -154.493062    ICU  1000HAB
# 1      US    AK  aleutians west  63.588753 -154.493062    ICU  1000HAB
# 2      US    AK       anchorage  63.588753 -154.493062  ACUTE  1000HAB
# 3      US    AK       anchorage  63.588753 -154.493062    ICU  1000HAB
# 4      US    AK       anchorage  63.588753 -154.493062  OTHER  1000HAB
#
#        beds  population  year  source  \
# 0  0.000000        3338  2019     khn
# 1  0.000000        5784  2019     khn
# 2  2.182916      298225  2018  arcgis
# 3  0.244782      298225  2019     khn
# 4  0.191131      298225  2019  arcgis
#
#                                           source_url
# 0  https://khn.org/news/as-coronavirus-spreads-wi...
# 1  https://khn.org/news/as-coronavirus-spreads-wi...
# 2  https://services1.arcgis.com/Hp6G80Pky0om7QvQ/...
# 3  https://khn.org/news/as-coronavirus-spreads-wi...
# ...

# %%
df.describe(include = 'all')
# Out:
#        country state      county          lat          lng  type  measure  \
# count     5713  5713        5713  5713.000000  5713.000000  5713     5713
# unique       1    51        1850          NaN          NaN     4        1
# top         US    TX  washington          NaN          NaN   ICU  1000HAB
# freq      5713   476          61          NaN          NaN  3142     5713
# mean       NaN   NaN         NaN    38.038590   -91.593572   NaN      NaN
# std        NaN   NaN         NaN     5.362105    13.230439   NaN      NaN
# min        NaN   NaN         NaN    19.898682  -155.665857   NaN      NaN
# 25%        NaN   NaN         NaN    33.836081   -99.901813   NaN      NaN
# 50%        NaN   NaN         NaN    37.964253   -89.398528   NaN      NaN
# 75%        NaN   NaN         NaN    41.492537   -82.907123   NaN      NaN
# max        NaN   NaN         NaN    63.588753   -69.445469   NaN      NaN
#
#                beds    population         year  source  \
# ...
